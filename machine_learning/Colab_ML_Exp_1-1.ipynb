# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def plot_img(fname):
  if fname == "":
    return
  plt.figure(figsize = (9,6))
  plt.imshow(mpimg.imread('/content/gdrive/My Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning/{}'.format(fname)))
  plt.show()

# %% [markdown]
# # tbl:results_dataset_random

# %% [markdown]
# ## AAL

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "AAL" --ds "abideids" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "AAL" --ds "abideids" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/AAL__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/AAL__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='AAL', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideids', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
#
#
# sens, spec, acc, auc
#
#
#
# train scores:
#
#  & 0.990 & 1.000 & 0.995 & 0.999 \\
#  & 1.000 & 0.989 & 0.994 & 1.000 \\
#  & 0.998 & 0.992 & 0.995 & 1.000 \\ \hline
# Averages & 0.996 & 0.994 & 0.995 & 0.999 \\
#
# val scores:
#
#  & 0.660 & 0.634 & 0.647 & 0.654 \\
#  & 0.702 & 0.634 & 0.668 & 0.655 \\
#  & 0.574 & 0.512 & 0.543 & 0.611 \\ \hline
# Averages & 0.645 & 0.593 & 0.619 & 0.640 \\
#
# train scores:
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "AAL" --ds "abideids" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "AAL" --ds "abideids" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/AAL__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/AAL__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='AAL', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideids', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_py', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
#
#
# sens, spec, acc, auc
#
#
#
# train scores:
#
#  & 0.000 & 1.000 & 0.500 & 0.500 \\
#  & 0.000 & 1.000 & 0.500 & 0.500 \\
#  & 0.957 & 0.917 & 0.937 & 0.983 \\ \hline
# Averages & 0.319 & 0.972 & 0.646 & 0.661 \\
#
# val scores:
#
#  & 0.000 & 1.000 & 0.500 & 0.500 \\
#  & 0.000 & 1.000 & 0.500 & 0.500 \\
#  & 0.596 & 0.561 & 0.578 & 0.597 \\ \hline
# Averages & 0.199 & 0.854 & 0.526 & 0.532 \\
#
# train scores:
# ...

# %% [markdown]
# ## cc_200

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "cc_200" --ds "abideids" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "cc_200" --ds "abideids" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/cc_200__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/cc_200__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='cc_200', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideids', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
#
#
# sens, spec, acc, auc
#
#
#
# train scores:
#
#  & 0.208 & 0.878 & 0.543 & 0.568 \\
#  & 1.000 & 1.000 & 1.000 & 1.000 \\
#  & 1.000 & 1.000 & 1.000 & 1.000 \\ \hline
# Averages & 0.736 & 0.959 & 0.848 & 0.856 \\
#
# val scores:
#
#  & 0.106 & 0.951 & 0.529 & 0.503 \\
#  & 0.660 & 0.561 & 0.610 & 0.692 \\
#  & 0.553 & 0.585 & 0.569 & 0.588 \\ \hline
# Averages & 0.440 & 0.699 & 0.569 & 0.594 \\
#
# train scores:
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "cc_200" --ds "abideids" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "cc_200" --ds "abideids" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/cc_200__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/cc_200__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='cc_200', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideids', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_py', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
#
#
# sens, spec, acc, auc
#
#
#
# train scores:
#
#  & 0.993 & 0.934 & 0.963 & 0.980 \\
#  & 0.950 & 0.970 & 0.960 & 0.971 \\
#  & 0.990 & 0.964 & 0.977 & 0.998 \\ \hline
# Averages & 0.978 & 0.956 & 0.967 & 0.983 \\
#
# val scores:
#
#  & 0.596 & 0.585 & 0.591 & 0.629 \\
#  & 0.745 & 0.610 & 0.677 & 0.702 \\
#  & 0.660 & 0.512 & 0.586 & 0.647 \\ \hline
# Averages & 0.667 & 0.569 & 0.618 & 0.659 \\
#
# train scores:
# ...

# %% [markdown]
# ## craddock_200

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "craddock_200" --ds "abideids" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "craddock_200" --ds "abideids" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/craddock_200__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/craddock_200__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='craddock_200', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideids', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "craddock_200" --ds "abideids" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "craddock_200" --ds "abideids" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/craddock_200__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/craddock_200__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='craddock_200', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideids', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_py', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %% [markdown]
# ## HO

# %% [markdown]
# ## HO_cort_maxprob_thr25-2mm

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "HO_cort_maxprob_thr25-2mm" --ds "abideids" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "HO_cort_maxprob_thr25-2mm" --ds "abideids" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/HO_cort_maxprob_thr25-2mm__bptf__no_nilearn_regress__28/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/HO_cort_maxprob_thr25-2mm__bptf__no_nilearn_regress__28/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='HO_cort_maxprob_thr25-2mm', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideids', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=28, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "HO_cort_maxprob_thr25-2mm" --ds "abideids" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "HO_cort_maxprob_thr25-2mm" --ds "abideids" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/HO_cort_maxprob_thr25-2mm__bptf__no_nilearn_regress__28/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/HO_cort_maxprob_thr25-2mm__bptf__no_nilearn_regress__28/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='HO_cort_maxprob_thr25-2mm', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideids', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_py', n_features=28, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %% [markdown]
# ## JAMA_IC7

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "JAMA_IC7" --ds "abideids" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "JAMA_IC7" --ds "abideids" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/JAMA_IC7__bptf__no_nilearn_regress__28/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/JAMA_IC7__bptf__no_nilearn_regress__28/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='JAMA_IC7', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideids', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=28, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
#
#
# sens, spec, acc, auc
#
#
#
# train scores:
#
#  & 0.593 & 0.652 & 0.623 & 0.646 \\
#  & 0.598 & 0.599 & 0.599 & 0.653 \\
#  & 0.622 & 0.591 & 0.607 & 0.642 \\ \hline
# Averages & 0.604 & 0.614 & 0.609 & 0.647 \\
#
# val scores:
#
#  & 0.532 & 0.634 & 0.583 & 0.642 \\
#  & 0.702 & 0.561 & 0.632 & 0.596 \\
#  & 0.489 & 0.683 & 0.586 & 0.614 \\ \hline
# Averages & 0.574 & 0.626 & 0.600 & 0.617 \\
#
# train scores:
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "JAMA_IC7" --ds "abideids" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "JAMA_IC7" --ds "abideids" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/JAMA_IC7__bptf__no_nilearn_regress__28/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/JAMA_IC7__bptf__no_nilearn_regress__28/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='JAMA_IC7', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideids', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_py', n_features=28, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
#
#
# sens, spec, acc, auc
#
#
#
# train scores:
#
#  & 0.620 & 0.605 & 0.612 & 0.646 \\
#  & 0.636 & 0.599 & 0.618 & 0.666 \\
#  & 0.722 & 0.464 & 0.593 & 0.648 \\ \hline
# Averages & 0.659 & 0.556 & 0.608 & 0.653 \\
#
# val scores:
#
#  & 0.489 & 0.512 & 0.501 & 0.573 \\
#  & 0.681 & 0.463 & 0.572 & 0.611 \\
#  & 0.574 & 0.463 & 0.519 & 0.592 \\ \hline
# Averages & 0.582 & 0.480 & 0.531 & 0.592 \\
#
# train scores:
# ...

# %% [markdown]
# ## JAMA_IC19

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "JAMA_IC19" --ds "abideids" --n_features 190 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "JAMA_IC19" --ds "abideids" --n_features 190 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/JAMA_IC19__bptf__no_nilearn_regress__190/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/JAMA_IC19__bptf__no_nilearn_regress__190/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='JAMA_IC19', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideids', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=190, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
#
#
# sens, spec, acc, auc
#
#
#
# train scores:
#
#  & 0.725 & 0.646 & 0.686 & 0.761 \\
#  & 0.821 & 0.630 & 0.725 & 0.818 \\
#  & 0.751 & 0.760 & 0.755 & 0.858 \\ \hline
# Averages & 0.766 & 0.679 & 0.722 & 0.812 \\
#
# val scores:
#
#  & 0.574 & 0.610 & 0.592 & 0.638 \\
#  & 0.745 & 0.366 & 0.555 & 0.615 \\
#  & 0.660 & 0.463 & 0.561 & 0.609 \\ \hline
# Averages & 0.660 & 0.480 & 0.570 & 0.621 \\
#
# train scores:
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "JAMA_IC19" --ds "abideids" --n_features 190 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "JAMA_IC19" --ds "abideids" --n_features 190 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/JAMA_IC19__bptf__no_nilearn_regress__190/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/JAMA_IC19__bptf__no_nilearn_regress__190/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='JAMA_IC19', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideids', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_py', n_features=190, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
#
#
# sens, spec, acc, auc
#
#
#
# train scores:
#
#  & 0.773 & 0.693 & 0.733 & 0.795 \\
#  & 0.725 & 0.696 & 0.711 & 0.785 \\
#  & 0.727 & 0.776 & 0.752 & 0.809 \\ \hline
# Averages & 0.742 & 0.722 & 0.732 & 0.796 \\
#
# val scores:
#
#  & 0.638 & 0.537 & 0.587 & 0.610 \\
#  & 0.574 & 0.610 & 0.592 & 0.627 \\
#  & 0.702 & 0.537 & 0.619 & 0.661 \\ \hline
# Averages & 0.638 & 0.561 & 0.600 & 0.633 \\
#
# train scores:
# ...

# %% [markdown]
# ## JAMA_IC52

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "JAMA_IC52" --ds "abideids" --n_features 1378 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "JAMA_IC52" --ds "abideids" --n_features 1378 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/JAMA_IC52__bptf__no_nilearn_regress__1378/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/JAMA_IC52__bptf__no_nilearn_regress__1378/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='JAMA_IC52', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideids', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=1378, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
#
#
# sens, spec, acc, auc
#
#
#
# train scores:
#
#  & 0.742 & 0.318 & 0.530 & 0.514 \\
#  & 0.902 & 0.978 & 0.940 & 0.972 \\
#  & 0.000 & 1.000 & 0.500 & 0.500 \\ \hline
# Averages & 0.548 & 0.765 & 0.657 & 0.662 \\
#
# val scores:
#
#  & 0.617 & 0.317 & 0.467 & 0.481 \\
#  & 0.511 & 0.610 & 0.560 & 0.608 \\
#  & 0.000 & 1.000 & 0.500 & 0.500 \\ \hline
# Averages & 0.376 & 0.642 & 0.509 & 0.530 \\
#
# train scores:
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "JAMA_IC52" --ds "abideids" --n_features 1378 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "JAMA_IC52" --ds "abideids" --n_features 1378 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/JAMA_IC52__bptf__no_nilearn_regress__1378/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/JAMA_IC52__bptf__no_nilearn_regress__1378/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='JAMA_IC52', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideids', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_py', n_features=1378, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
#
#
# sens, spec, acc, auc
#
#
#
# train scores:
#
#  & 0.892 & 0.749 & 0.820 & 0.922 \\
#  & 0.933 & 0.931 & 0.932 & 0.976 \\
#  & 0.938 & 0.906 & 0.922 & 0.977 \\ \hline
# Averages & 0.921 & 0.862 & 0.891 & 0.958 \\
#
# val scores:
#
#  & 0.596 & 0.537 & 0.566 & 0.653 \\
#  & 0.574 & 0.561 & 0.568 & 0.627 \\
#  & 0.617 & 0.463 & 0.540 & 0.598 \\ \hline
# Averages & 0.596 & 0.520 & 0.558 & 0.626 \\
#
# train scores:
# ...

# %% [markdown]
# ## schaefer_100

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "schaefer_100" --ds "abideids" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "schaefer_100" --ds "abideids" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/schaefer_100__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/schaefer_100__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='schaefer_100', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideids', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
#
#
# sens, spec, acc, auc
#
#
#
# train scores:
#
#  & 0.983 & 0.815 & 0.899 & 0.925 \\
#  & 0.871 & 0.939 & 0.905 & 0.952 \\
#  & 0.000 & 1.000 & 0.500 & 0.500 \\ \hline
# Averages & 0.618 & 0.918 & 0.768 & 0.792 \\
#
# val scores:
#
#  & 0.702 & 0.512 & 0.607 & 0.629 \\
#  & 0.596 & 0.561 & 0.578 & 0.565 \\
#  & 0.000 & 1.000 & 0.500 & 0.500 \\ \hline
# Averages & 0.433 & 0.691 & 0.562 & 0.565 \\
#
# train scores:
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "schaefer_100" --ds "abideids" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "schaefer_100" --ds "abideids" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/schaefer_100__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/schaefer_100__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='schaefer_100', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideids', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_py', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %% [markdown]
# ## schaefer_400

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "schaefer_400" --ds "abideids" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "schaefer_400" --ds "abideids" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/schaefer_400__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/schaefer_400__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='schaefer_400', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideids', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# tcmalloc: large alloc 1391632384 bytes == 0x7fa6000 @  0x7f3d54a901e7 0x7f3d52559ca1 0x7f3d525c39c5 0x7f3d525c455e 0x7f3d5265da6e 0x4f8925 0x4fa6c0 0x4f6128 0x4f7d60 0x4f876d 0x4fa6c0 0x4f6128 0x4f7d60 0x4f876d 0x4f98c7 0x4f6128 0x4f7d60 0x4f876d 0x4f98c7 0x4f6128 0x4f9023 0x6415b2 0x64166a 0x643730 0x62b26e 0x4b4cb0 0x7f3d5468db97 0x5bdf6a
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "schaefer_400" --ds "abideids" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "schaefer_400" --ds "abideids" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/schaefer_400__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/schaefer_400__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='schaefer_400', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideids', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_py', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# tcmalloc: large alloc 1391632384 bytes == 0x69da000 @  0x7f69650211e7 0x7f6962aeaca1 0x7f6962b549c5 0x7f6962b5555e 0x7f6962beea6e 0x4f8925 0x4fa6c0 0x4f6128 0x4f7d60 0x4f876d 0x4fa6c0 0x4f6128 0x4f7d60 0x4f876d 0x4f98c7 0x4f6128 0x4f7d60 0x4f876d 0x4f98c7 0x4f6128 0x4f9023 0x6415b2 0x64166a 0x643730 0x62b26e 0x4b4cb0 0x7f6964c1eb97 0x5bdf6a
# ...

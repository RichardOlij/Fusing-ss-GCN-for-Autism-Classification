# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def plot_img(fname):
  if fname == "":
    return
  plt.figure(figsize = (9,6))
  plt.imshow(mpimg.imread('/content/gdrive/My Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning/{}'.format(fname)))
  plt.show()

# %% [markdown]
# # tbl:results_polynomials

# %% [markdown]
# ## craddock_200, abideboth

# %% [markdown]
# ### tf

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "craddock_200" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True" --polynomial_degree 3
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "craddock_200" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True" --polynomial_degree 3
plot_img("")
plot_img("")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='craddock_200', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideboth', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
#
#
# sens, spec, acc, auc
#
#
#
# train scores:
#
#  & 0.995 & 0.994 & 0.995 & 1.000 \\
#  & 0.000 & 1.000 & 0.500 & 0.500 \\
#  & 0.000 & 1.000 & 0.500 & 0.500 \\ \hline
# Averages & 0.332 & 0.998 & 0.665 & 0.667 \\
#
# val scores:
#
#  & 0.589 & 0.614 & 0.602 & 0.669 \\
#  & 0.000 & 1.000 & 0.500 & 0.500 \\
#  & 0.000 & 1.000 & 0.500 & 0.500 \\ \hline
# Averages & 0.196 & 0.871 & 0.534 & 0.556 \\
#
# train scores:
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "craddock_200" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True" --polynomial_degree 2
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "craddock_200" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True" --polynomial_degree 2
plot_img("")
plot_img("")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='craddock_200', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideboth', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=2000, polynomial_degree=2, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# No datadict found
# Reducing the feature dimensionality to 10000.
# Exact file is found and used.
# Reducing the feature dimensionality to 6000.
# Exact file is found and used.
# Reducing the feature dimensionality to 4000.
# Exact file is found and used.
# Reducing the feature dimensionality to 3000.
# Exact file is found and used.
# Reducing the feature dimensionality to 2000.
# Exact file is found and used.
# Creating fixed adjacency matrix.
# Calculating Chebyshev polynomials up to order 2...
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "craddock_200" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True" --polynomial_degree 1
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "craddock_200" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True" --polynomial_degree 1
plot_img("")
plot_img("")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='craddock_200', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideboth', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=2000, polynomial_degree=1, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# No datadict found
# Reducing the feature dimensionality to 10000.
# Exact file is found and used.
# Reducing the feature dimensionality to 6000.
# Exact file is found and used.
# Reducing the feature dimensionality to 4000.
# Exact file is found and used.
# Reducing the feature dimensionality to 3000.
# Exact file is found and used.
# Reducing the feature dimensionality to 2000.
# Exact file is found and used.
# Creating fixed adjacency matrix.
# Calculating Chebyshev polynomials up to order 1...
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "craddock_200" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True" --polynomial_degree 0
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "craddock_200" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True" --polynomial_degree 0
plot_img("")
plot_img("")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='craddock_200', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideboth', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=2000, polynomial_degree=0, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# No datadict found
# Reducing the feature dimensionality to 10000.
# Exact file is found and used.
# Reducing the feature dimensionality to 6000.
# Exact file is found and used.
# Reducing the feature dimensionality to 4000.
# Exact file is found and used.
# Reducing the feature dimensionality to 3000.
# Exact file is found and used.
# Reducing the feature dimensionality to 2000.
# Exact file is found and used.
# Creating fixed adjacency matrix.
# Calculating Chebyshev polynomials up to order 0...
# ...

# %% [markdown]
# ### py

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "craddock_200" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True" --polynomial_degree 3 
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "craddock_200" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True" --polynomial_degree 3 
plot_img("")
plot_img("")

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "craddock_200" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True" --polynomial_degree 2
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "craddock_200" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True" --polynomial_degree 2
plot_img("")
plot_img("")

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "craddock_200" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True" --polynomial_degree 1
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "craddock_200" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True" --polynomial_degree 1
plot_img("")
plot_img("")

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "craddock_200" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True" --polynomial_degree 0
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "craddock_200" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True" --polynomial_degree 0
plot_img("")
plot_img("")

# %% [markdown]
# ## JAMA_IC7, NYU

# %% [markdown]
# ### tf

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "JAMA_IC7" --ds "NYU" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True" --polynomial_degree 3
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "JAMA_IC7" --ds "NYU" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True" --polynomial_degree 3
plot_img("")
plot_img("")

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "JAMA_IC7" --ds "NYU" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True" --polynomial_degree 2
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "JAMA_IC7" --ds "NYU" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True" --polynomial_degree 2
plot_img("")
plot_img("")

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "JAMA_IC7" --ds "NYU" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True" --polynomial_degree 1
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "JAMA_IC7" --ds "NYU" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True" --polynomial_degree 1
plot_img("")
plot_img("")

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "JAMA_IC7" --ds "NYU" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True" --polynomial_degree 0
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "JAMA_IC7" --ds "NYU" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True" --polynomial_degree 0
plot_img("")
plot_img("")

# %% [markdown]
# ### py

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "JAMA_IC7" --ds "NYU" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True" --polynomial_degree 3
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "JAMA_IC7" --ds "NYU" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True" --polynomial_degree 3
plot_img("")
plot_img("")

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "JAMA_IC7" --ds "NYU" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True" --polynomial_degree 2
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "JAMA_IC7" --ds "NYU" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True" --polynomial_degree 2
plot_img("")
plot_img("")

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "JAMA_IC7" --ds "NYU" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True" --polynomial_degree 1
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py 
plot_img("")--max_fold 3 --atlas "JAMA_IC7" --ds "NYU" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True" --polynomial_degree 1
plot_img("")

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "JAMA_IC7" --ds "NYU" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True" --polynomial_degree 0
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "JAMA_IC7" --ds "NYU" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True" --polynomial_degree 0
plot_img("")
plot_img("")

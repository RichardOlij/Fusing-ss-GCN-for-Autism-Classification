# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def plot_img(fname):
  if fname == "":
    return
  plt.figure(figsize = (9,6))
  plt.imshow(mpimg.imread('/content/gdrive/My Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning/{}'.format(fname)))
  plt.show()

# %% [markdown]
# # tbl:results_dataset_random

# %% [markdown]
# ## AAL

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "AAL" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "AAL" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/AAL__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/AAL__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='AAL', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideboth', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "AAL" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "AAL" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/AAL__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/AAL__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='AAL', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideboth', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_py', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %% [markdown]
# ## cc_200

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "cc_200" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "cc_200" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/cc_200__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/cc_200__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='cc_200', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideboth', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "cc_200" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "cc_200" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/cc_200__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/cc_200__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='cc_200', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideboth', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_py', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %% [markdown]
# ## craddock_200

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "craddock_200" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "craddock_200" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/craddock_200__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/craddock_200__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='craddock_200', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideboth', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "craddock_200" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "craddock_200" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/craddock_200__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/craddock_200__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='craddock_200', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideboth', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_py', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %% [markdown]
# ## HO

# %% [markdown]
# ## HO_cort_maxprob_thr25-2mm

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "HO_cort_maxprob_thr25-2mm" --ds "abideboth" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "HO_cort_maxprob_thr25-2mm" --ds "abideboth" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/HO_cort_maxprob_thr25-2mm__bptf__no_nilearn_regress__28/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/HO_cort_maxprob_thr25-2mm__bptf__no_nilearn_regress__28/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='HO_cort_maxprob_thr25-2mm', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideboth', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=28, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "HO_cort_maxprob_thr25-2mm" --ds "abideboth" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "HO_cort_maxprob_thr25-2mm" --ds "abideboth" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/HO_cort_maxprob_thr25-2mm__bptf__no_nilearn_regress__28/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/HO_cort_maxprob_thr25-2mm__bptf__no_nilearn_regress__28/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='HO_cort_maxprob_thr25-2mm', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideboth', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_py', n_features=28, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %% [markdown]
# ## JAMA_IC7

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "JAMA_IC7" --ds "abideboth" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "JAMA_IC7" --ds "abideboth" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/JAMA_IC7__bptf__no_nilearn_regress__28/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/JAMA_IC7__bptf__no_nilearn_regress__28/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='JAMA_IC7', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideboth', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=28, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "JAMA_IC7" --ds "abideboth" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "JAMA_IC7" --ds "abideboth" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/JAMA_IC7__bptf__no_nilearn_regress__28/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/JAMA_IC7__bptf__no_nilearn_regress__28/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='JAMA_IC7', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideboth', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_py', n_features=28, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %% [markdown]
# ## JAMA_IC19

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "JAMA_IC19" --ds "abideboth" --n_features 190 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "JAMA_IC19" --ds "abideboth" --n_features 190 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/JAMA_IC19__bptf__no_nilearn_regress__190/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/JAMA_IC19__bptf__no_nilearn_regress__190/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='JAMA_IC19', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideboth', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=190, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "JAMA_IC19" --ds "abideboth" --n_features 190 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "JAMA_IC19" --ds "abideboth" --n_features 190 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/JAMA_IC19__bptf__no_nilearn_regress__190/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/JAMA_IC19__bptf__no_nilearn_regress__190/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='JAMA_IC19', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideboth', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_py', n_features=190, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %% [markdown]
# ## JAMA_IC_52

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "JAMA_IC52" --ds "abideboth" --n_features 1378 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "JAMA_IC52" --ds "abideboth" --n_features 1378 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/JAMA_IC52__bptf__no_nilearn_regress__1378/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/JAMA_IC52__bptf__no_nilearn_regress__1378/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='JAMA_IC52', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideboth', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=1378, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "JAMA_IC52" --ds "abideboth" --n_features 1378 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "JAMA_IC52" --ds "abideboth" --n_features 1378 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/JAMA_IC52__bptf__no_nilearn_regress__1378/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/JAMA_IC52__bptf__no_nilearn_regress__1378/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='JAMA_IC52', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideboth', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_py', n_features=1378, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %% [markdown]
# ## schaefer_100

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "schaefer_100" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "schaefer_100" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/schaefer_100__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/schaefer_100__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='schaefer_100', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideboth', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "schaefer_100" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "schaefer_100" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/schaefer_100__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/schaefer_100__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='schaefer_100', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideboth', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_py', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %% [markdown]
# ## schaefer_400

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "schaefer_400" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "schaefer_400" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/schaefer_400__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/schaefer_400__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='schaefer_400', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideboth', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# tcmalloc: large alloc 1391632384 bytes == 0x79cc000 @  0x7f1b8dca51e7 0x7f1b8b76eca1 0x7f1b8b7d89c5 0x7f1b8b7d955e 0x7f1b8b872a6e 0x4f8925 0x4fa6c0 0x4f6128 0x4f7d60 0x4f876d 0x4fa6c0 0x4f6128 0x4f7d60 0x4f876d 0x4f98c7 0x4f6128 0x4f7d60 0x4f876d 0x4f98c7 0x4f6128 0x4f9023 0x6415b2 0x64166a 0x643730 0x62b26e 0x4b4cb0 0x7f1b8d8a2b97 0x5bdf6a
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "schaefer_400" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "schaefer_400" --ds "abideboth" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/schaefer_400__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideboth/schaefer_400__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='schaefer_400', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideboth', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_py', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# tcmalloc: large alloc 1391632384 bytes == 0x75f0000 @  0x7f6a6bcce1e7 0x7f6a69797ca1 0x7f6a698019c5 0x7f6a6980255e 0x7f6a6989ba6e 0x4f8925 0x4fa6c0 0x4f6128 0x4f7d60 0x4f876d 0x4fa6c0 0x4f6128 0x4f7d60 0x4f876d 0x4f98c7 0x4f6128 0x4f7d60 0x4f876d 0x4f98c7 0x4f6128 0x4f9023 0x6415b2 0x64166a 0x643730 0x62b26e 0x4b4cb0 0x7f6a6b8cbb97 0x5bdf6a
# ...

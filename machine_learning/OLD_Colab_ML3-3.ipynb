# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def plot_img(fname):
  if fname == "":
    return
  plt.figure(figsize = (9,6))
  plt.imshow(mpimg.imread('/content/gdrive/My Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning/{}'.format(fname)))
  plt.show()

# %% [markdown]
# #Test stuff

# %% [markdown]
# #Check difference between tf and py for the normal fixed adjacency:

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --atlas "AAL" --ds "abideids" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --atlas "AAL" --ds "abideids" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/AAL__bptf__no_nilearn_regress/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/AAL__bptf__no_nilearn_regress/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='AAL', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideids', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=-1, model='parisot_tf', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
#
#
# sens, spec, acc, auc
#
#
#
# train scores:
#
#  & 1.000 & 1.000 & 1.000 & 1.000 \\
#  & 0.981 & 0.978 & 0.979 & 0.993 \\
#  & 0.911 & 0.693 & 0.802 & 0.852 \\
#  & 0.983 & 0.989 & 0.986 & 0.999 \\
#  & 0.940 & 0.953 & 0.947 & 0.976 \\
#  & 0.995 & 1.000 & 0.998 & 0.999 \\
#  & 0.000 & 1.000 & 0.500 & 0.500 \\
#  & 0.000 & 1.000 & 0.500 & 0.500 \\
#  & 1.000 & 0.997 & 0.999 & 0.999 \\
#  & 1.000 & 0.994 & 0.997 & 1.000 \\ \hline
# Averages & 0.781 & 0.961 & 0.871 & 0.882 \\
#
# val scores:
#
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --atlas "AAL" --ds "abideids" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --atlas "AAL" --ds "abideids" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/AAL__bptf__no_nilearn_regress/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__abideids/AAL__bptf__no_nilearn_regress/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='AAL', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='abideids', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=-1, model='parisot_py', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
#
#
# sens, spec, acc, auc
#
#
#
# train scores:
#
#  & 0.916 & 0.909 & 0.913 & 0.948 \\
#  & 0.919 & 0.961 & 0.940 & 0.979 \\
#  & 0.830 & 0.953 & 0.892 & 0.951 \\
#  & 0.675 & 0.937 & 0.806 & 0.963 \\
#  & 0.677 & 0.945 & 0.811 & 0.827 \\
#  & 0.685 & 0.939 & 0.812 & 0.959 \\
#  & 0.943 & 0.959 & 0.951 & 0.983 \\
#  & 0.000 & 1.000 & 0.500 & 0.804 \\
#  & 0.888 & 0.975 & 0.932 & 0.958 \\
#  & 0.905 & 0.986 & 0.945 & 0.985 \\ \hline
# Averages & 0.744 & 0.956 & 0.850 & 0.935 \\
#
# val scores:
#
# ...

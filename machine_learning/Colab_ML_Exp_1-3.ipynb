# %%
# from google.colab import drive
# drive.mount('/content/gdrive')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def plot_img(fname):
  if fname == "":
    return
  plt.figure(figsize = (9,6))
  plt.imshow(mpimg.imread('/content/gdrive/My Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning/{}'.format(fname)))
  plt.show()

# %% [markdown]
# # tbl:results_dataset_random

# %% [markdown]
# ## AAL

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "AAL" --ds "NYU" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "AAL" --ds "NYU" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/AAL__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/AAL__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='AAL', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='NYU', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "AAL" --ds "NYU" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "AAL" --ds "NYU" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/AAL__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/AAL__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='AAL', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='NYU', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_py', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %% [markdown]
# ## cc_200

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "cc_200" --ds "NYU" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "cc_200" --ds "NYU" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/cc_200__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/cc_200__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='cc_200', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='NYU', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "cc_200" --ds "NYU" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "cc_200" --ds "NYU" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/cc_200__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/cc_200__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='cc_200', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='NYU', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_py', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %% [markdown]
# ## craddock_200

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "craddock_200" --ds "NYU" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "craddock_200" --ds "NYU" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/craddock_200__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/craddock_200__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='craddock_200', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='NYU', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "craddock_200" --ds "NYU" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "craddock_200" --ds "NYU" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/craddock_200__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/craddock_200__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='craddock_200', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='NYU', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_py', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %% [markdown]
# ## HO

# %% [markdown]
# ## HO_cort_maxprob_thr25-2mm

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "HO_cort_maxprob_thr25-2mm" --ds "NYU" --n_features 1176 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "HO_cort_maxprob_thr25-2mm" --ds "NYU" --n_features 1176 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/HO_cort_maxprob_thr25-2mm__bptf__no_nilearn_regress__1176/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/HO_cort_maxprob_thr25-2mm__bptf__no_nilearn_regress__1176/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='HO_cort_maxprob_thr25-2mm', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='NYU', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=1176, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "HO_cort_maxprob_thr25-2mm" --ds "NYU" --n_features 1176 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "HO_cort_maxprob_thr25-2mm" --ds "NYU" --n_features 1176 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/HO_cort_maxprob_thr25-2mm__bptf__no_nilearn_regress__1176/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/HO_cort_maxprob_thr25-2mm__bptf__no_nilearn_regress__1176/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='HO_cort_maxprob_thr25-2mm', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='NYU', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_py', n_features=1176, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %% [markdown]
# ## JAMA_IC7

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "JAMA_IC7" --ds "NYU" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "JAMA_IC7" --ds "NYU" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/JAMA_IC7__bptf__no_nilearn_regress__28/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/JAMA_IC7__bptf__no_nilearn_regress__28/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='JAMA_IC7', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='NYU', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=28, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "JAMA_IC7" --ds "NYU" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "JAMA_IC7" --ds "NYU" --n_features 28 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/JAMA_IC7__bptf__no_nilearn_regress__28/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/JAMA_IC7__bptf__no_nilearn_regress__28/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='JAMA_IC7', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='NYU', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_py', n_features=28, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %% [markdown]
# ## JAMA_IC19

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "JAMA_IC19" --ds "NYU" --n_features 190 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "JAMA_IC19" --ds "NYU" --n_features 190 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/JAMA_IC19__bptf__no_nilearn_regress__190/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/JAMA_IC19__bptf__no_nilearn_regress__190/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='JAMA_IC19', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='NYU', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=190, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "JAMA_IC19" --ds "NYU" --n_features 190 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "JAMA_IC19" --ds "NYU" --n_features 190 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/JAMA_IC19__bptf__no_nilearn_regress__190/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/JAMA_IC19__bptf__no_nilearn_regress__190/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='JAMA_IC19', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='NYU', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_py', n_features=190, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %% [markdown]
# ## IC_52

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "JAMA_IC52" --ds "NYU" --n_features 1378 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "JAMA_IC52" --ds "NYU" --n_features 1378 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/JAMA_IC52__bptf__no_nilearn_regress__1378/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/JAMA_IC52__bptf__no_nilearn_regress__1378/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='JAMA_IC52', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='NYU', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=1378, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "JAMA_IC52" --ds "NYU" --n_features 1378 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "JAMA_IC52" --ds "NYU" --n_features 1378 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/JAMA_IC52__bptf__no_nilearn_regress__1378/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/JAMA_IC52__bptf__no_nilearn_regress__1378/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='JAMA_IC52', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='NYU', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_py', n_features=1378, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %% [markdown]
# ## schaefer_100

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "schaefer_100" --ds "NYU" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "schaefer_100" --ds "NYU" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/schaefer_100__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/schaefer_100__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='schaefer_100', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='NYU', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "schaefer_100" --ds "NYU" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "schaefer_100" --ds "NYU" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/schaefer_100__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/schaefer_100__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='schaefer_100', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='NYU', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_py', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 3 folds
# Ignored fold 1, since store_data_dicts already contains 3 folds
# Ignored fold 2, since store_data_dicts already contains 3 folds
# ...

# %% [markdown]
# ## schaefer_400

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "schaefer_400" --ds "NYU" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "schaefer_400" --ds "NYU" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_tf" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/schaefer_400__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/schaefer_400__bptf__no_nilearn_regress__2000/parisot_tf__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='schaefer_400', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='NYU', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_tf', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# tcmalloc: large alloc 1391632384 bytes == 0x7e02000 @  0x7f567e45b1e7 0x7f567bf24ca1 0x7f567bf8e9c5 0x7f567bf8f55e 0x7f567c028a6e 0x4f8925 0x4fa6c0 0x4f6128 0x4f7d60 0x4f876d 0x4fa6c0 0x4f6128 0x4f7d60 0x4f876d 0x4f98c7 0x4f6128 0x4f7d60 0x4f876d 0x4f98c7 0x4f6128 0x4f9023 0x6415b2 0x64166a 0x643730 0x62b26e 0x4b4cb0 0x7f567e058b97 0x5bdf6a
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_baseline.py --max_fold 3 --atlas "schaefer_400" --ds "NYU" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_baseline.py --max_fold 3 --atlas "schaefer_400" --ds "NYU" --n_features 2000 --adj_type "fixed" --adj_fixed_specs "gender_0, site_0" --dataset_type "random" --model "parisot_py" --features_sparsity "True"
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/schaefer_400__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_train.png")
plot_img("generated_data_baseline/datadict/fixed_['gender_0', 'site_0']__3__True__random__NYU/schaefer_400__bptf__no_nilearn_regress__2000/parisot_py__0.005__0.0005__16__0.3/fig_val.png")
# Out:
# Arguments: Namespace(adj_fixed_specs=['gender_0', 'site_0'], adj_threshold=-1.0, adj_type='fixed', atlas='schaefer_400', bptf='bptf', confounds='no_nilearn_regress', dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='NYU', epochs=150, features_sparsity=True, hidden_parisot=16, learning_rate_parisot=0.005, max_fold=3, model='parisot_py', n_features=2000, polynomial_degree=3, print_epoch=10, save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# tcmalloc: large alloc 1391632384 bytes == 0x751a000 @  0x7f474a8ab1e7 0x7f4748374ca1 0x7f47483de9c5 0x7f47483df55e 0x7f4748478a6e 0x4f8925 0x4fa6c0 0x4f6128 0x4f7d60 0x4f876d 0x4fa6c0 0x4f6128 0x4f7d60 0x4f876d 0x4f98c7 0x4f6128 0x4f7d60 0x4f876d 0x4f98c7 0x4f6128 0x4f9023 0x6415b2 0x64166a 0x643730 0x62b26e 0x4b4cb0 0x7f474a4a8b97 0x5bdf6a
# ...

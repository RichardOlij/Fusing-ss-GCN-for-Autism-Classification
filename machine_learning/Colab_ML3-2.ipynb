# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def plot_img(fname):
  if fname == "":
    return
  plt.figure(figsize = (9,6))
  plt.imshow(mpimg.imread('/content/gdrive/My Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning/{}'.format(fname)))
  plt.show()

# %% [markdown]
# #Test stuff

# %% [markdown]
# ## Block

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_combined.py --model "cnn" --epochs 250 --print_epoch 50 --max_fold 5 --cnn_model 9 --raw_data_preprocess_method 'vmhc' --ds "abideboth" --save_model_epoch 50
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_combined.py --model "cnn" --epochs 250 --print_epoch 50 --max_fold 5 --cnn_model 9 --raw_data_preprocess_method 'vmhc' --ds "abideboth" --save_model_epoch 50
# plot_img("generated_data_combined/datadict/-1.0__3__True__random__abideboth/cnn9__0.001__0.9__32__vmhc/fig_train.png")
# plot_img("generated_data_combined/datadict/-1.0__3__True__random__abideboth/cnn9__0.001__0.9__32__vmhc/fig_val.png")

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_combined.py --model "parisot_py" --epochs 250 --print_epoch 50 --max_fold 5 --cnn_model 9 --raw_data_preprocess_method 'vmhc' --ds "abideboth" --save_model_epoch 50
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_combined.py --model "parisot_py" --epochs 250 --print_epoch 50 --max_fold 5 --cnn_model 9 --raw_data_preprocess_method 'vmhc' --ds "abideboth" --save_model_epoch 50
# plot_img("")
# plot_img("")

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_combined.py --model "parisot_tf" --epochs 250 --print_epoch 50 --max_fold 5 --cnn_model 9 --raw_data_preprocess_method 'vmhc' --ds "abideboth" --save_model_epoch 50
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_combined.py --model "parisot_tf" --epochs 250 --print_epoch 50 --max_fold 5 --cnn_model 9 --raw_data_preprocess_method 'vmhc' --ds "abideboth" --save_model_epoch 50
# plot_img("")
# plot_img("")

# %% [markdown]
# ##Block

# %% [markdown]
# ### features_sparsity True

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_combined.py --model "cnn" --epochs 250 --print_epoch 50 --max_fold 5 --cnn_model 9 --raw_data_preprocess_method 'reho' --ds "NYU" --save_model_epoch 50 --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_combined.py --model "cnn" --epochs 250 --print_epoch 50 --max_fold 5 --cnn_model 9 --raw_data_preprocess_method 'reho' --ds "NYU" --save_model_epoch 50 --features_sparsity "True"
plot_img("generated_data_combined/datadict/-1.0__3__True__random__NYU/cnn9__0.001__0.9__32__reho/fig_train.png")
plot_img("generated_data_combined/datadict/-1.0__3__True__random__NYU/cnn9__0.001__0.9__32__reho/fig_val.png")
# Out:
# Arguments: Namespace(adj_threshold=-1.0, batch_size_3dcnn=32, cnn_model=9, dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='NYU', epochs=250, features_sparsity=True, hidden_parisot=16, learning_rate_3dcnn=0.001, learning_rate_parisot=0.005, max_fold=5, model='cnn', momentum_3dcnn=0.9, polynomial_degree=3, print_epoch=50, raw_data_preprocess_method='reho', save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# Loading datadict.
# Ignored fold 0, since store_data_dicts already contains 2 folds
# Ignored fold 1, since store_data_dicts already contains 2 folds
# F-2, E-1: train: loss 0.7214, acc 0.4038, auc 0.4020, sens 0.262378, spec 0.545294. val: loss 0.6934, acc 0.5000, auc 0.5455, sens 1.000000, spec 0.000000. duration 1.56.
# Saving the current model.
# Saving the current predictions.
# No variation in the labels, just the accuracy is calculated.
# No variation in the labels, just the accuracy is calculated.
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_combined.py --model "parisot_py" --epochs 250 --print_epoch 50 --max_fold 5 --cnn_model 9 --raw_data_preprocess_method 'reho' --ds "NYU" --save_model_epoch 50 --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_combined.py --model "parisot_py" --epochs 250 --print_epoch 50 --max_fold 5 --cnn_model 9 --raw_data_preprocess_method 'reho' --ds "NYU" --save_model_epoch 50 --features_sparsity "True"
# plot_img("")
# plot_img("")
# Out:
# Arguments: Namespace(adj_threshold=-1.0, batch_size_3dcnn=32, cnn_model=9, dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='NYU', epochs=250, features_sparsity=True, hidden_parisot=16, learning_rate_3dcnn=0.001, learning_rate_parisot=0.005, max_fold=5, model='parisot_py', momentum_3dcnn=0.9, polynomial_degree=3, print_epoch=50, raw_data_preprocess_method='reho', save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# No datadict found
# Calculating Chebyshev polynomials up to order 3...
# F-0, E-1: train: loss 0.6910, acc 0.5000, auc 0.4153, sens 1.000000, spec 0.000000. val: loss 0.6885, acc 0.5000, auc 0.3182, sens 1.000000, spec 0.000000. duration 0.06.
# Saving the current model.
# Saving the current predictions.
# F-0, E-51: train: loss 0.6831, acc 0.5000, auc 0.5225, sens 1.000000, spec 0.000000. val: loss 0.6792, acc 0.5000, auc 0.6818, sens 1.000000, spec 0.000000. duration 0.03.
# Saving the current model.
# Saving the current predictions.
# ...

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_combined.py --model "parisot_tf" --epochs 250 --print_epoch 50 --max_fold 5 --cnn_model 9 --raw_data_preprocess_method 'reho' --ds "NYU" --save_model_epoch 50 --features_sparsity "True"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_combined.py --model "parisot_tf" --epochs 250 --print_epoch 50 --max_fold 5 --cnn_model 9 --raw_data_preprocess_method 'reho' --ds "NYU" --save_model_epoch 50 --features_sparsity "True"
# plot_img("")
# plot_img("")
# Out:
# Arguments: Namespace(adj_threshold=-1.0, batch_size_3dcnn=32, cnn_model=9, dataset_type='random', device=device(type='cuda'), dropout_parisot=0.3, ds='NYU', epochs=250, features_sparsity=True, hidden_parisot=16, learning_rate_3dcnn=0.001, learning_rate_parisot=0.005, max_fold=5, model='parisot_tf', momentum_3dcnn=0.9, polynomial_degree=3, print_epoch=50, raw_data_preprocess_method='reho', save_model_epoch=50, seed=0, weight_decay_parisot=0.0005)
#
# No datadict found

# %% [markdown]
# ### features_sparsity False

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_combined.py --model "cnn" --epochs 250 --print_epoch 50 --max_fold 5 --cnn_model 9 --raw_data_preprocess_method 'reho' --ds "NYU" --save_model_epoch 50 --features_sparsity "False"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_combined.py --model "cnn" --epochs 250 --print_epoch 50 --max_fold 5 --cnn_model 9 --raw_data_preprocess_method 'reho' --ds "NYU" --save_model_epoch 50 --features_sparsity "False"
plot_img("generated_data_combined/datadict/-1.0__3__True__random__NYU/cnn9__0.001__0.9__32__reho/fig_train.png")
plot_img("generated_data_combined/datadict/-1.0__3__True__random__NYU/cnn9__0.001__0.9__32__reho/fig_val.png")

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_combined.py --model "parisot_py" --epochs 250 --print_epoch 50 --max_fold 5 --cnn_model 9 --raw_data_preprocess_method 'reho' --ds "NYU" --save_model_epoch 50 --features_sparsity "False"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_combined.py --model "parisot_py" --epochs 250 --print_epoch 50 --max_fold 5 --cnn_model 9 --raw_data_preprocess_method 'reho' --ds "NYU" --save_model_epoch 50 --features_sparsity "False"
# plot_img("")
# plot_img("")

# %%
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python main_combined.py --model "parisot_tf" --epochs 250 --print_epoch 50 --max_fold 5 --cnn_model 9 --raw_data_preprocess_method 'reho' --ds "NYU" --save_model_epoch 50 --features_sparsity "False"
# !cd /content/gdrive/My\ Drive/Thesis_Colab/_Public_repository/AMC-UvA-GCN-Classification-Neuroimaging/machine_learning && python read_results_combined.py --model "parisot_tf" --epochs 250 --print_epoch 50 --max_fold 5 --cnn_model 9 --raw_data_preprocess_method 'reho' --ds "NYU" --save_model_epoch 50 --features_sparsity "False"
# plot_img("")
# plot_img("")

# %% [markdown]
# ## Block
